# %%
import pandas as pd
import io

# %%
# !pip install -q kaggle

# %%
# !mkdir ~/.kaggle
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
# !cp kaggle.json  ~/.kaggle

# %%
# !kaggle datasets download -d mohamedafsal007/house-price-dataset-of-india
# Out:
# ...
# house-price-dataset-of-india.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !unzip /content/house-price-dataset-of-india.zip
# Out:
# Archive:  /content/house-price-dataset-of-india.zip
# replace House Price India.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
df = pd.read_csv('/content/house-price-dataset-of-india.zip')
df.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
df.shape
# Out:
# (14620, 23)

# %%
df.tail()
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 14615  6762830250  42734                   2                  1.5
# 14616  6762830339  42734                   3                  2.0
# 14617  6762830618  42734                   2                  1.0
# 14618  6762830709  42734                   4                  1.0
# 14619  6762831463  42734                   3                  1.0
#
#        living area  lot area  number of floors  waterfront present  \
# 14615         1556     20000               1.0                   0
# 14616         1680      7000               1.5                   0
# 14617         1070      6120               1.0                   0
# 14618         1030      6621               1.0                   0
# 14619          900      4770               1.0                   0
#
#        number of views  condition of the house  ...  Built Year  \
# 14615                0                       4  ...        1957
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14620 entries, 0 to 14619
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     14620 non-null  int64
#  1   Date                                   14620 non-null  int64
#  2   number of bedrooms                     14620 non-null  int64
#  3   number of bathrooms                    14620 non-null  float64
#  4   living area                            14620 non-null  int64
#  5   lot area                               14620 non-null  int64
#  6   number of floors                       14620 non-null  float64
#  7   waterfront present                     14620 non-null  int64
#  8   number of views                        14620 non-null  int64
#  9   condition of the house                 14620 non-null  int64
# ...

# %%
df.isnull().any()
# Out:
# id                                       False
# Date                                     False
# number of bedrooms                       False
# number of bathrooms                      False
# living area                              False
# lot area                                 False
# number of floors                         False
# waterfront present                       False
# number of views                          False
# condition of the house                   False
# grade of the house                       False
# Area of the house(excluding basement)    False
# Area of the basement                     False
# Built Year                               False
# Renovation Year                          False
# Postal Code                              False
# Lattitude                                False
# Longitude                                False
# living_area_renov                        False
# lot_area_renov                           False
# ...

# %%
df.describe()
# Out:
#                  id          Date  number of bedrooms  number of bathrooms  \
# count  1.462000e+04  14620.000000        14620.000000         14620.000000
# mean   6.762821e+09  42604.538646            3.379343             2.129583
# std    6.237575e+03     67.347991            0.938719             0.769934
# min    6.762810e+09  42491.000000            1.000000             0.500000
# 25%    6.762815e+09  42546.000000            3.000000             1.750000
# 50%    6.762821e+09  42600.000000            3.000000             2.250000
# 75%    6.762826e+09  42662.000000            4.000000             2.500000
# max    6.762832e+09  42734.000000           33.000000             8.000000
#
#         living area      lot area  number of floors  waterfront present  \
# count  14620.000000  1.462000e+04      14620.000000        14620.000000
# mean    2098.262996  1.509328e+04          1.502360            0.007661
# std      928.275721  3.791962e+04          0.540239            0.087193
# ...

# %%
df.Longitude.unique()
# Out:
# array([-114.557, -114.47 , -114.468, -114.321, -114.485, -114.59 ,
#        -114.05 , -114.482, -114.598, -114.391, -114.215, -114.459,
#        -114.177, -114.511, -114.515, -114.3  , -114.574, -114.395,
#        -114.568, -114.236, -114.06 , -114.304, -114.225, -114.348,
#        -114.496, -114.259, -114.512, -114.212, -114.412, -114.471,
#        -113.924, -113.908, -114.582, -114.367, -114.554, -114.587,
#        -114.181, -114.532, -114.325, -114.323, -114.324, -114.351,
#        -114.53 , -114.38 , -114.573, -114.371, -114.381, -114.555,
#        -114.341, -114.297, -114.087, -114.262, -114.529, -114.518,
#        -114.245, -114.553, -114.224, -114.493, -114.096, -113.977,
#        -114.383, -114.503, -114.343, -114.55 , -114.334, -114.585,
#        -114.207, -113.953, -114.479, -114.216, -114.406, -114.176,
#        -114.476, -114.238, -114.35 , -114.349, -114.263, -114.172,
#        -114.299, -114.372, -114.228, -114.385, -114.219, -114.5  ,
# ...

# %%
df.Longitude.value_counts()
# Out:
# -114.552    73
# -114.562    73
# -114.490    72
# -114.480    69
# -114.553    68
#             ..
# -114.036     1
# -114.096     1
# -113.994     1
# -114.111     1
# -113.891     1
# Name: Longitude, Length: 716, dtype: int64

# %%
df.corr()
# Out:
#                                              id      Date  number of bedrooms  \
# id                                     1.000000  0.045966           -0.329034
# Date                                   0.045966  1.000000           -0.015663
# number of bedrooms                    -0.329034 -0.015663            1.000000
# number of bathrooms                   -0.516909 -0.026485            0.509784
# living area                           -0.648127 -0.021958            0.570526
# lot area                              -0.100269  0.004392            0.034416
# number of floors                      -0.312305 -0.010335            0.177294
# waterfront present                    -0.112937  0.012006           -0.006257
# number of views                       -0.293004 -0.004782            0.078665
# condition of the house                -0.045061 -0.027402            0.026597
# grade of the house                    -0.673448 -0.033097            0.352945
# ...

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.displot(df.Price)

# %%
sns.distplot(df.Price)
# Out:
# <ipython-input-19-5e080168c38c>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Price)
# <Axes: xlabel='Price', ylabel='Density'>

# %%
sns.distplot(df.Date)
# Out:
# <ipython-input-20-82d9cb3bf0f8>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Date)
# <Axes: xlabel='Date', ylabel='Density'>

# %%
sns.distplot(df.Date)
# Out:
# <ipython-input-21-82d9cb3bf0f8>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Date)
# <Axes: xlabel='Date', ylabel='Density'>

# %%
plt.pie(df.Date.value_counts())
# Out:
# ([<matplotlib.patches.Wedge at 0x7f3c9fc68070>,
# ...
#  [Text(1.0994879520065575, 0.03355954994373648, ''),
#   Text(1.0956290479883886, 0.0979642241027688, ''),
#   Text(1.0883807271883459, 0.1594596898434448, ''),
#   Text(1.0778726468364237, 0.21952347756411414, ''),
#   Text(1.0646493671211674, 0.2766256045424895, ''),
#   Text(1.0489740685336628, 0.33113955297417197, ''),
#   Text(1.0308398100268346, 0.3838870746246085, ''),
#   Text(1.0102421896670086, 0.4352134168621276, ''),
#   Text(0.9871951541324587, 0.48522750092857614, ''),
#   Text(0.9617886813502137, 0.5338188198505345, ''),
#   Text(0.9341172013032107, 0.5808829953006516, ''),
#   Text(0.9044137628976067, 0.6261275792371647, ''),
#   Text(0.8728085729476057, 0.6694812880052466, ''),
#   Text(0.8394326765186244, 0.7108816931056664, ''),
#   Text(0.8044174231549167, 0.7502750224583007, ''),
#   Text(0.7677246976278361, 0.7877809268142051, ''),
#   Text(0.7296390511351837, 0.8231809370111465, ''),
# ...

# %%
sns.barplot(x=df.Date.value_counts().index)
# Out:
# <Axes: >

# %%
sns.scatterplot(x=df.id,y=df.Date)
# Out:
# <Axes: xlabel='id', ylabel='Date'>

# %%
sns.lineplot(x=df.id,y=df.Date)
# Out:
# <Axes: xlabel='id', ylabel='Date'>

# %%
sns.lineplot(x=df.Date,y=df.Price)
# Out:
# <Axes: xlabel='Date', ylabel='Price'>

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
sns.boxplot(df.Date)
# Out:
# <Axes: >

# %%
df.median()
# Out:
# id                                       6.762821e+09
# Date                                     4.260000e+04
# number of bedrooms                       3.000000e+00
# number of bathrooms                      2.250000e+00
# living area                              1.930000e+03
# lot area                                 7.620000e+03
# number of floors                         1.500000e+00
# waterfront present                       0.000000e+00
# number of views                          0.000000e+00
# condition of the house                   3.000000e+00
# grade of the house                       7.000000e+00
# Area of the house(excluding basement)    1.580000e+03
# Area of the basement                     0.000000e+00
# Built Year                               1.975000e+03
# Renovation Year                          0.000000e+00
# Postal Code                              1.220320e+05
# Lattitude                                5.280640e+01
# ...
